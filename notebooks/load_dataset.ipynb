# %%
from datasets import load_dataset

# %%
# Load the preformatted data
dataset = load_dataset("imagefolder", data_dir="../scripts/talks_dset/")
# Out:
# Found cached dataset imagefolder (/home/francois/.cache/huggingface/datasets/imagefolder/default-707a43041f7c6519/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
# 100%|██████████| 1/1 [00:00<00:00, 880.60it/s]

# %%
print(dataset['train'][1]['conversation'])
# Out:
# User: #disc #disturbed #clumpy #tidal-debris forming #arms possible #overlap upper #spiral
#
# User: Major merger
#
# User: Or maybe an incredible overlap.
# But just classify what you see !

# %%
dataset['train'][1]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>
